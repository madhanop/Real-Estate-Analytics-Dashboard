# %%
from IPython.display import Image, display

display(Image(filename=r"C:\Users\Admin\Downloads\nb-logo-trans-1.png",width=400))

# %%
import pandas as pd
import numpy as np

# %%
prp=pd.read_csv(r"C:\Users\Admin\Desktop\Magic Bricks\Property Details.csv")
bk=pd.read_csv(r"C:\Users\Admin\Desktop\Magic Bricks\Booking Details.csv")
cd=pd.read_csv(r"C:\Users\Admin\Desktop\Magic Bricks\Customer Details.csv")
sd=pd.read_csv(r"C:\Users\Admin\Desktop\Magic Bricks\Sale Details.csv")
ad=pd.read_csv(r"C:\Users\Admin\Desktop\Magic Bricks\Agent Details.csv")

# %%
prp.head()
# Out:
#   property_id        property_name property_type        city state  \
# 0        P101   Green Valley Villa         Villa     Chennai    TN
# 1        P102    Skyline Residency     Apartment  Perambalur    TN
# 2        P103  Lakeview Apartments     Apartment   Bangalore    KA
# 3        P104    Madhan Apartments     Apartment  Coimbatore    TN
# 4        P105      Sunrise Heights     Apartment       Kochi    KL
#
#   listed_date    price  area_sqft  bedrooms  bathrooms agent_id
# 0    3/5/2019  8549300       4938         4          2     A001
# 1    3/6/2019  6162548       1870         3          2     A002
# 2    3/7/2019  4839127       2378         3          2     A003
# 3    3/8/2019  8991950       2476         2          2     A004
# 4    3/9/2019  7939013       1644         2          2     A005

# %%
prp.shape
# Out:
# (3000, 11)

# %%
bk.head()
# Out:
#   customer_id booking_id     booking_type property_type  \
# 0        C001       B001  Direct Purchase         Villa
# 1        C002       B002      Pre-Booking     Apartment
# 2        C003       B003     Loan Booking     Apartment
# 3        C004       B004           Resale     Apartment
# 4        C005       B005  Direct Purchase     Apartment
#
#                                         property_img agent_id sale_id
# 0  https://image2url.com/r2/default/images/177536...     A001    S001
# 1  https://image2url.com/r2/default/images/177536...     A002    S002
# 2  https://image2url.com/r2/default/images/177536...     A003    S003
# 3  https://image2url.com/r2/default/images/177536...     A004    S004
# 4  https://image2url.com/r2/default/images/177536...     A005    S005

# %%
bk.shape
# Out:
# (3000, 7)

# %%
cd.head()
# Out:
#   customer_id        customer_name        city  budget_min  budget_max  \
# 0        C001        David Dejesus     Chennai     4675584     8343049
# 1        C002     Jesse Garczynski  Perambalur     5188199     7840630
# 2        C003          Thomas Cote   Bangalore     5817150     6247689
# 3        C004  Christopher Johnson  Coimbatore     4864945     6389177
# 4        C005      Jimmie Silkwood       Kochi     5313126     8673309
#
#   preferred_property_type
# 0                   Villa
# 1               Apartment
# 2               Apartment
# 3               Apartment
# 4               Apartment

# %%
cd.shape
# Out:
# (3000, 6)

# %%
sd.head()
# Out:
#   sale_id property_id sale_date  sale_price      buyer_name payment_method
# 0    S001        P101  2/2/2025     6271541    Merle Ingram           Cash
# 1    S002        P102  2/3/2025     7500508      John Mayes      Bank Loan
# 2    S003        P103  2/4/2025     5812486    Carlos Wille            EMI
# 3    S004        P104  2/5/2025     8968866  Michael Bryant         Cheque
# 4    S005        P105  2/6/2025     5336196   Paula Douglas           Cash

# %%
sd.shape
# Out:
# (3000, 6)

# %%
ad.head()
# Out:
#   agent_id      agent_name  contact_number               agency_name  \
# 0     A001    Merle Ingram      6382749878              Prime Realty
# 1     A002      John Mayes      6382749879  Elite Property Solutions
# 2     A003    Carlos Wille      6382749880         Urban Nest Realty
# 3     A004  Michael Bryant      6382749881        Dream Homes Agency
# 4     A005   Paula Douglas      6382749882         Golden Key Realty
#
#    experience_years booking_id
# 0                 4       B001
# 1                 6       B002
# 2                 6       B003
# 3                 6       B004
# 4                 3       B005

# %%
ad.shape
# Out:
# (3000, 6)

# %%
prp.isna().sum()
# Out:
# property_id      0
# property_name    0
# property_type    0
# city             0
# state            0
# listed_date      0
# price            0
# area_sqft        0
# bedrooms         0
# bathrooms        0
# agent_id         0
# dtype: int64

# %%
bk.isna().sum()
# Out:
# customer_id      0
# booking_id       0
# booking_type     0
# property_type    0
# property_img     0
# agent_id         0
# sale_id          0
# dtype: int64

# %%
cd.isna().sum()
# Out:
# customer_id                0
# customer_name              0
# city                       0
# budget_min                 0
# budget_max                 0
# preferred_property_type    0
# dtype: int64

# %%
sd.isna().sum()
# Out:
# sale_id           0
# property_id       0
# sale_date         0
# sale_price        0
# buyer_name        0
# payment_method    0
# dtype: int64

# %%
ad.isna().sum()
# Out:
# agent_id            0
# agent_name          0
# contact_number      0
# agency_name         0
# experience_years    0
# booking_id          0
# dtype: int64

# %%
prp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_id    3000 non-null   object
#  1   property_name  3000 non-null   object
#  2   property_type  3000 non-null   object
#  3   city           3000 non-null   object
#  4   state          3000 non-null   object
#  5   listed_date    3000 non-null   object
#  6   price          3000 non-null   int64
#  7   area_sqft      3000 non-null   int64
#  8   bedrooms       3000 non-null   int64
#  9   bathrooms      3000 non-null   int64
#  10  agent_id       3000 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 257.9+ KB

# %%
bk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    3000 non-null   object
#  1   booking_id     3000 non-null   object
#  2   booking_type   3000 non-null   object
#  3   property_type  3000 non-null   object
#  4   property_img   3000 non-null   object
#  5   agent_id       3000 non-null   object
#  6   sale_id        3000 non-null   object
# dtypes: object(7)
# memory usage: 164.2+ KB

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              3000 non-null   object
#  1   customer_name            3000 non-null   object
#  2   city                     3000 non-null   object
#  3   budget_min               3000 non-null   int64
#  4   budget_max               3000 non-null   int64
#  5   preferred_property_type  3000 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 140.8+ KB

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sale_id         3000 non-null   object
#  1   property_id     3000 non-null   object
#  2   sale_date       3000 non-null   object
#  3   sale_price      3000 non-null   int64
#  4   buyer_name      3000 non-null   object
#  5   payment_method  3000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 140.8+ KB

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   agent_id          3000 non-null   object
#  1   agent_name        3000 non-null   object
#  2   contact_number    3000 non-null   int64
#  3   agency_name       3000 non-null   object
#  4   experience_years  3000 non-null   int64
#  5   booking_id        3000 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 140.8+ KB

# %%
prp.dtypes
# Out:
# property_id              object
# property_name            object
# property_type            object
# city                     object
# state                    object
# listed_date      datetime64[ns]
# price                     int64
# area_sqft                 int64
# bedrooms                  int64
# bathrooms                 int64
# agent_id                 object
# dtype: object

# %%
prp["listed_date"]=pd.to_datetime(prp["listed_date"])
sd["sale_date"]=pd.to_datetime(sd["sale_date"])

# %%
sd.dtypes
# Out:
# sale_id                   object
# property_id               object
# sale_date         datetime64[ns]
# sale_price                 int64
# buyer_name                object
# payment_method            object
# dtype: object

# %%
prp.columns
# Out:
# Index(['property_id', 'property_name', 'property_type', 'city', 'state',
#        'listed_date', 'price', 'area_sqft', 'bedrooms', 'bathrooms',
#        'agent_id'],
#       dtype='object')

# %%
bk.columns
# Out:
# Index(['customer_id', 'booking_id', 'booking_type', 'property_type',
#        'property_img', 'agent_id', 'sale_id'],
#       dtype='object')

# %%
sd.columns
# Out:
# Index(['sale_id', 'property_id', 'sale_date', 'sale_price', 'buyer_name',
#        'payment_method'],
#       dtype='object')

# %%
cd.columns
# Out:
# Index(['customer_id', 'customer_name', 'city', 'budget_min', 'budget_max',
#        'preferred_property_type'],
#       dtype='object')

# %%
ad.columns
# Out:
# Index(['agent_id', 'agent_name', 'contact_number', 'agency_name',
#        'experience_years', 'booking_id'],
#       dtype='object')
